# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ● In this task we have to Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
# ● As a business manager, try to find out the weak areas where we can work to make more profit.
# ● and what at all business problems we can derive by exploring the data .

# %% [markdown]
# ### Author: Vaishnavi R.

# %%
#Importing necessary modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importing Dataset

# %% [markdown]
# Dataset : https://bit.ly/3i4rbWl

# %%
dataset = pd.read_csv('SampleSuperstore.csv')

# %%
dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Handling missing data

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### Handling duplicate records

# %%
duplicate=dataset.duplicated()
print(duplicate.sum())
dataset[duplicate]
# Out:
# 17
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %% [markdown]
# We have 17 duplicates values

# %% [markdown]
# ### Dropping the duplicate values

# %%
dataset.drop_duplicates(inplace=True)
dataset.shape
# Out:
# (9977, 13)

# %% [markdown]
# 17 duplicate values are removed and number of rows decreased from 9994 to 9977.

# %% [markdown]
# ### Displaying the unique data

# %%
dataset.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ### Performing Data Visualization for more information

# %%
#Correlation Heatmap between attributes
sns.heatmap(dataset.corr(),annot=True)

# %% [markdown]
# * Correlation between Profit and Sales is moderate. * Almost no Correlation between Discount and Sales or Discount and Quantity. * Negative Correlation between Discount and Profit is low. Hence, Discount given by the store is not useful as it is not able to increase the production of store and its profit.

# %% [markdown]
# ### State Wise Analysis

# %%
dataset['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %% [markdown]
# ### Transaction per state

# %%
plt.figure(figsize=(20,15))
sns.countplot(x=dataset['State'])
plt.xticks(rotation=50)
plt.title('States')
plt.show()

# %% [markdown]
# When the data of different states is analysed, we can conclude that California recieves maximum amount of profit with maximum sales when compared to the other states. Then comes New York and Texas.

# %%
s=(dataset['Segment'].value_counts()/len(dataset['Segment'])*100)
s
# Out:
# Consumer       51.949484
# Corporate      30.219505
# Home Office    17.831011
# Name: Segment, dtype: float64

# %%
s.plot(kind='bar',color="olive",title='Segment')

# %% [markdown]
# From the Graph we can conclude that
#
# * 50% of people belongs to consumer class
# * Nearly 30% of people belongs to corporate class.
# * Nearly 20% of people belongs to home office class.

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
(dataset['Ship Mode'].value_counts()/len(dataset['Ship Mode']))*100
# Out:
# Standard Class    59.687281
# Second Class      19.474792
# First Class       15.405432
# Same Day           5.432495
# Name: Ship Mode, dtype: float64

# %%
((dataset['Ship Mode'].value_counts()/len(dataset['Ship Mode']))*100).plot(kind="bar", color="grey")

# %% [markdown]
# Conclusions when the ship mode data is analysed:
# * Maximum number of shipments belong to tha standard class
#
# * whereas, very less number of shipments are done on the same day (10%)

# %% [markdown]
# ### Categry Wise Analysis

# %%
dataset['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
(dataset['Category'].value_counts()/len(dataset['Category']))*100
# Out:
# Office Supplies    60.258595
# Furniture          21.228826
# Technology         18.512579
# Name: Category, dtype: float64

# %%
sns.countplot(dataset['Category'])

# %%
cat_dataset = dataset.groupby(['Category'])[['Category','Sales','Profit']].mean()
cat_dataset.head()
# Out:
#                       Sales     Profit
# Category
# Furniture        350.002981   8.697740
# Office Supplies  119.550107  20.353403
# Technology       452.709276  78.752002

# %% [markdown]
# Maximum sales and profits is in technology

# %%
plt.figure(figsize=(10,10))
dataset.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.show()
# Out:
# <ipython-input-54-527ed589d3ea>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataset.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize = (20,5))
sns.countplot(dataset['Sub-Category'])

# %%
plt.figure(figsize=(10,10))
dataset.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.show()
# Out:
# <ipython-input-35-0bef9dc371cd>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataset.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(10,5))
sns.lineplot("Discount", "Profit", data=dataset, color='b',label='Discount')
plt.legend()
plt.show()

# %%
sns.barplot(x=dataset.Region, y=dataset.Profit,hue=dataset.Category)

# %% [markdown]
# Furniture is facing loss in the Central region and Technology gets maximum profit in the Southern region.

# %% [markdown]
# ### Counting repeatable states in the sample file

# %%
dataset['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
def state_data_viewer(states):
    """plots the turnover generated by different product categories and sub-categories for the list of given states
    Args:
       states -List all the states you want to plot for 
       Returns:
       None
       """
    product_data = dataset.groupby(['State'])
    for state in states:
        data = product_data.get_group(state).groupby(['Category'])
        fig,ax =plt.subplots(1, 3, figsize= (30,4))
        fig.suptitle(state, fontsize=14)
        ax_index =0
        for cat in ['Furniture', 'Office Supplies', 'Technology']:
            cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
            sns.barplot(x=cat_data.Profit, y= cat_data.index, ax =ax[ax_index])
            ax[ax_index].set_ylabel(cat)
            ax_index+=1
        
        fig.show()

# %%
states =['California', 'Mississippi', 'Texas','Washington','Arizona']
state_data_viewer(states)
# Out:
# <ipython-input-51-63e1a0653906>:20: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# From the above data Visualization we can see that states and category where sale and profit are high and less. We can improve the profit in other states where there is low sale or profit by giving discount and various offers.
